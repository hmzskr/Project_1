# %%
# Dependencies
import requests
from config import ykey
import pandas as pd
import numpy as np

# %% [markdown]
# Cities from article '10 best foodie cities in America' on CNBC.
# https://www.cnbc.com/2018/11/05/wallethub-best-food-cities-in-america.html

# %%
# List of cities
cities = ['Portland, OR', 'San Francisco, CA', 'Miami, FL', 'New York, NY', 'Los Angeles, CA', 'Orlando, FL', 'Las Vegas, NV', 'Seattle, WA', 'San Diego, CA', 'Austin, TX']

cities
# Out:
# ['Portland, OR',
#  'San Francisco, CA',
#  'Miami, FL',
#  'New York, NY',
#  'Los Angeles, CA',
#  'Orlando, FL',
#  'Las Vegas, NV',
#  'Seattle, WA',
#  'San Diego, CA',
#  'Austin, TX']

# %%
name_list = []
city_list = []
state_list = []
category_list = []
rating_list = []
review_count_list = []
price_list = []

# %%
url='https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % ykey}

for city in cities:
    params = {'location' : city, 'term': 'food', 'limit' : '50', 'sortby' : 'rating, review_count'}
    response = requests.get(url, params, headers=headers)
    data = response.json()
    restaurant_data = data['businesses']
    count = 1

    for restaurant in restaurant_data:
        print(f'Retrieving restaurant {count} in {city}')
        
        for category in restaurant['categories']:
            
            name_list.append(restaurant['name'])
            city_list.append(restaurant['location']['city'])
            state_list.append(restaurant['location']['state'])
            category_list.append(category['title'])
            rating_list.append(restaurant['rating'])
            review_count_list.append(restaurant['review_count'])
            
            try:                
                price_list.append(restaurant['price'])
            
            except:
                price_list.append('')     
            
        count = count + 1
# Out:
# Retrieving restaurant 1 in Portland, OR
# Retrieving restaurant 2 in Portland, OR
# Retrieving restaurant 3 in Portland, OR
# Retrieving restaurant 4 in Portland, OR
# Retrieving restaurant 5 in Portland, OR
# Retrieving restaurant 6 in Portland, OR
# Retrieving restaurant 7 in Portland, OR
# Retrieving restaurant 8 in Portland, OR
# Retrieving restaurant 9 in Portland, OR
# Retrieving restaurant 10 in Portland, OR
# Retrieving restaurant 11 in Portland, OR
# Retrieving restaurant 12 in Portland, OR
# Retrieving restaurant 13 in Portland, OR
# Retrieving restaurant 14 in Portland, OR
# Retrieving restaurant 15 in Portland, OR
# Retrieving restaurant 16 in Portland, OR
# Retrieving restaurant 17 in Portland, OR
# Retrieving restaurant 18 in Portland, OR
# Retrieving restaurant 19 in Portland, OR
# Retrieving restaurant 20 in Portland, OR
# Retrieving restaurant 21 in Portland, OR
# Retrieving restaurant 22 in Portland, OR
# Retrieving restaurant 23 in Portland, OR
# Retrieving restaurant 24 in Portland, OR
# Retrieving restaurant 25 in Portland, OR
# Retrieving restaurant 26 in Portland, OR
# Retrieving restaurant 27 in Portland, OR
# Retrieving restaurant 28 in Portland, OR
# Retrieving restaurant 29 in Portland, OR
# Retrieving restaurant 30 in Portland, OR
# Retrieving restaurant 31 in Portland, OR
# Retrieving restaurant 32 in Portland, OR
# Retrieving restaurant 33 in Portland, OR
# Retrieving restaurant 34 in Portland, OR
# Retrieving restaurant 35 in Portland, OR
# Retrieving restaurant 36 in Portland, OR
# Retrieving restaurant 37 in Portland, OR
# Retrieving restaurant 38 in Portland, OR
# Retrieving restaurant 39 in Portland, OR
# Retrieving restaurant 40 in Portland, OR
# Retrieving restaurant 41 in Portland, OR
# Retrieving restaurant 42 in Portland, OR
# Retrieving restaurant 14 in Miami, FL
# Retrieving restaurant 15 in Miami, FL
# Retrieving restaurant 16 in Miami, FL
# Retrieving restaurant 17 in Miami, FL
# Retrieving restaurant 18 in Miami, FL
# Retrieving restaurant 19 in Miami, FL
# Retrieving restaurant 20 in Miami, FL
# Retrieving restaurant 21 in Miami, FL
# Retrieving restaurant 22 in Miami, FL
# Retrieving restaurant 23 in Miami, FL
# Retrieving restaurant 24 in Miami, FL
# Retrieving restaurant 25 in Miami, FL
# Retrieving restaurant 26 in Miami, FL
# Retrieving restaurant 27 in Miami, FL
# Retrieving restaurant 28 in Miami, FL
# Retrieving restaurant 29 in Miami, FL
# Retrieving restaurant 30 in Miami, FL
# Retrieving restaurant 31 in Miami, FL
# Retrieving restaurant 32 in Miami, FL
# Retrieving restaurant 33 in Miami, FL
# Retrieving restaurant 34 in Miami, FL
# Retrieving restaurant 35 in Miami, FL
# Retrieving restaurant 36 in Miami, FL
# Retrieving restaurant 37 in Miami, FL
# Retrieving restaurant 38 in Miami, FL
# Retrieving restaurant 39 in Miami, FL
# Retrieving restaurant 40 in Miami, FL
# Retrieving restaurant 41 in Miami, FL
# Retrieving restaurant 42 in Miami, FL
# Retrieving restaurant 43 in Miami, FL
# Retrieving restaurant 44 in Miami, FL
# Retrieving restaurant 45 in Miami, FL
# Retrieving restaurant 46 in Miami, FL
# Retrieving restaurant 47 in Miami, FL
# Retrieving restaurant 48 in Miami, FL
# Retrieving restaurant 49 in Miami, FL
# Retrieving restaurant 50 in Miami, FL
# Retrieving restaurant 1 in New York, NY
# Retrieving restaurant 2 in New York, NY
# Retrieving restaurant 3 in New York, NY
# Retrieving restaurant 4 in New York, NY
# Retrieving restaurant 5 in New York, NY
# Retrieving restaurant 6 in New York, NY
# Retrieving restaurant 7 in New York, NY
# Retrieving restaurant 8 in New York, NY
# Retrieving restaurant 9 in New York, NY
# Retrieving restaurant 10 in New York, NY
# Retrieving restaurant 11 in New York, NY
# Retrieving restaurant 12 in New York, NY
# Retrieving restaurant 13 in New York, NY
# Retrieving restaurant 14 in New York, NY
# Retrieving restaurant 15 in New York, NY
# Retrieving restaurant 16 in New York, NY
# Retrieving restaurant 17 in New York, NY
# Retrieving restaurant 18 in New York, NY
# Retrieving restaurant 19 in New York, NY
# Retrieving restaurant 20 in New York, NY
# Retrieving restaurant 21 in New York, NY
# Retrieving restaurant 22 in New York, NY
# Retrieving restaurant 23 in New York, NY
# Retrieving restaurant 24 in New York, NY
# Retrieving restaurant 25 in New York, NY
# Retrieving restaurant 26 in New York, NY
# Retrieving restaurant 27 in New York, NY
# Retrieving restaurant 28 in New York, NY
# Retrieving restaurant 29 in New York, NY
# Retrieving restaurant 30 in New York, NY
# Retrieving restaurant 31 in New York, NY
# Retrieving restaurant 32 in New York, NY
# Retrieving restaurant 33 in New York, NY
# Retrieving restaurant 34 in New York, NY
# Retrieving restaurant 35 in New York, NY
# Retrieving restaurant 36 in New York, NY
# Retrieving restaurant 37 in New York, NY
# Retrieving restaurant 38 in New York, NY
# Retrieving restaurant 39 in New York, NY
# Retrieving restaurant 40 in New York, NY
# Retrieving restaurant 41 in New York, NY
# Retrieving restaurant 42 in New York, NY
# Retrieving restaurant 43 in New York, NY
# Retrieving restaurant 44 in New York, NY
# Retrieving restaurant 45 in New York, NY
# Retrieving restaurant 46 in New York, NY
# Retrieving restaurant 47 in New York, NY
# Retrieving restaurant 48 in New York, NY
# Retrieving restaurant 49 in New York, NY
# Retrieving restaurant 50 in New York, NY
# Retrieving restaurant 1 in Los Angeles, CA
# Retrieving restaurant 2 in Los Angeles, CA
# Retrieving restaurant 3 in Los Angeles, CA
# Retrieving restaurant 4 in Los Angeles, CA
# Retrieving restaurant 5 in Los Angeles, CA
# Retrieving restaurant 6 in Los Angeles, CA
# Retrieving restaurant 7 in Los Angeles, CA
# Retrieving restaurant 8 in Los Angeles, CA
# Retrieving restaurant 9 in Los Angeles, CA
# Retrieving restaurant 10 in Los Angeles, CA
# Retrieving restaurant 11 in Los Angeles, CA
# Retrieving restaurant 12 in Los Angeles, CA
# Retrieving restaurant 13 in Los Angeles, CA
# Retrieving restaurant 14 in Los Angeles, CA
# Retrieving restaurant 15 in Los Angeles, CA
# Retrieving restaurant 16 in Los Angeles, CA
# Retrieving restaurant 17 in Los Angeles, CA
# Retrieving restaurant 18 in Los Angeles, CA
# Retrieving restaurant 19 in Los Angeles, CA
# Retrieving restaurant 20 in Los Angeles, CA
# Retrieving restaurant 21 in Los Angeles, CA
# Retrieving restaurant 22 in Los Angeles, CA
# Retrieving restaurant 23 in Los Angeles, CA
# Retrieving restaurant 24 in Los Angeles, CA
# Retrieving restaurant 25 in Los Angeles, CA
# Retrieving restaurant 26 in Los Angeles, CA
# Retrieving restaurant 27 in Los Angeles, CA
# Retrieving restaurant 28 in Los Angeles, CA
# Retrieving restaurant 29 in Los Angeles, CA
# Retrieving restaurant 30 in Los Angeles, CA
# Retrieving restaurant 31 in Los Angeles, CA
# Retrieving restaurant 32 in Los Angeles, CA
# Retrieving restaurant 33 in Los Angeles, CA
# Retrieving restaurant 34 in Los Angeles, CA
# Retrieving restaurant 35 in Los Angeles, CA
# Retrieving restaurant 36 in Los Angeles, CA
# Retrieving restaurant 37 in Los Angeles, CA
# Retrieving restaurant 38 in Los Angeles, CA
# Retrieving restaurant 39 in Los Angeles, CA
# Retrieving restaurant 40 in Los Angeles, CA
# Retrieving restaurant 41 in Los Angeles, CA
# Retrieving restaurant 42 in Los Angeles, CA
# Retrieving restaurant 43 in Los Angeles, CA
# Retrieving restaurant 44 in Los Angeles, CA
# Retrieving restaurant 45 in Los Angeles, CA
# Retrieving restaurant 46 in Los Angeles, CA
# Retrieving restaurant 47 in Los Angeles, CA
# Retrieving restaurant 48 in Los Angeles, CA
# Retrieving restaurant 49 in Los Angeles, CA
# Retrieving restaurant 50 in Los Angeles, CA
# Retrieving restaurant 1 in Orlando, FL
# Retrieving restaurant 2 in Orlando, FL
# Retrieving restaurant 3 in Orlando, FL
# Retrieving restaurant 4 in Orlando, FL
# Retrieving restaurant 5 in Orlando, FL
# Retrieving restaurant 6 in Orlando, FL
# Retrieving restaurant 7 in Orlando, FL
# Retrieving restaurant 8 in Orlando, FL
# Retrieving restaurant 9 in Orlando, FL
# Retrieving restaurant 10 in Orlando, FL
# Retrieving restaurant 31 in Las Vegas, NV
# Retrieving restaurant 32 in Las Vegas, NV
# Retrieving restaurant 33 in Las Vegas, NV
# Retrieving restaurant 34 in Las Vegas, NV
# Retrieving restaurant 35 in Las Vegas, NV
# Retrieving restaurant 36 in Las Vegas, NV
# Retrieving restaurant 37 in Las Vegas, NV
# Retrieving restaurant 38 in Las Vegas, NV
# Retrieving restaurant 39 in Las Vegas, NV
# Retrieving restaurant 40 in Las Vegas, NV
# Retrieving restaurant 41 in Las Vegas, NV
# Retrieving restaurant 42 in Las Vegas, NV
# Retrieving restaurant 43 in Las Vegas, NV
# Retrieving restaurant 44 in Las Vegas, NV
# Retrieving restaurant 45 in Las Vegas, NV
# Retrieving restaurant 46 in Las Vegas, NV
# Retrieving restaurant 47 in Las Vegas, NV
# Retrieving restaurant 48 in Las Vegas, NV
# Retrieving restaurant 49 in Las Vegas, NV
# Retrieving restaurant 50 in Las Vegas, NV
# Retrieving restaurant 1 in Seattle, WA
# Retrieving restaurant 2 in Seattle, WA
# Retrieving restaurant 3 in Seattle, WA
# Retrieving restaurant 4 in Seattle, WA
# Retrieving restaurant 5 in Seattle, WA
# Retrieving restaurant 6 in Seattle, WA
# Retrieving restaurant 7 in Seattle, WA
# Retrieving restaurant 8 in Seattle, WA
# Retrieving restaurant 9 in Seattle, WA
# Retrieving restaurant 10 in Seattle, WA
# Retrieving restaurant 11 in Seattle, WA
# Retrieving restaurant 12 in Seattle, WA
# Retrieving restaurant 13 in Seattle, WA
# Retrieving restaurant 14 in Seattle, WA
# Retrieving restaurant 15 in Seattle, WA
# Retrieving restaurant 16 in Seattle, WA
# Retrieving restaurant 17 in Seattle, WA
# Retrieving restaurant 18 in Seattle, WA
# Retrieving restaurant 19 in Seattle, WA
# Retrieving restaurant 20 in Seattle, WA
# Retrieving restaurant 21 in Seattle, WA
# Retrieving restaurant 22 in Seattle, WA
# Retrieving restaurant 23 in Seattle, WA
# Retrieving restaurant 24 in Seattle, WA
# Retrieving restaurant 25 in Seattle, WA
# Retrieving restaurant 26 in Seattle, WA
# Retrieving restaurant 27 in Seattle, WA
# Retrieving restaurant 28 in Seattle, WA
# Retrieving restaurant 29 in Seattle, WA
# Retrieving restaurant 30 in Seattle, WA
# Retrieving restaurant 31 in Seattle, WA
# Retrieving restaurant 32 in Seattle, WA
# Retrieving restaurant 33 in Seattle, WA
# Retrieving restaurant 34 in Seattle, WA
# Retrieving restaurant 35 in Seattle, WA
# Retrieving restaurant 36 in Seattle, WA
# Retrieving restaurant 37 in Seattle, WA
# Retrieving restaurant 38 in Seattle, WA
# Retrieving restaurant 39 in Seattle, WA
# Retrieving restaurant 40 in Seattle, WA
# Retrieving restaurant 41 in Seattle, WA
# Retrieving restaurant 42 in Seattle, WA
# Retrieving restaurant 43 in Seattle, WA
# Retrieving restaurant 44 in Seattle, WA
# Retrieving restaurant 45 in Seattle, WA
# Retrieving restaurant 46 in Seattle, WA
# Retrieving restaurant 47 in Seattle, WA
# Retrieving restaurant 48 in Seattle, WA
# Retrieving restaurant 49 in Seattle, WA
# Retrieving restaurant 50 in Seattle, WA
# Retrieving restaurant 1 in San Diego, CA
# Retrieving restaurant 2 in San Diego, CA
# Retrieving restaurant 27 in Austin, TX
# Retrieving restaurant 28 in Austin, TX
# Retrieving restaurant 29 in Austin, TX
# Retrieving restaurant 30 in Austin, TX
# Retrieving restaurant 31 in Austin, TX
# Retrieving restaurant 32 in Austin, TX
# Retrieving restaurant 33 in Austin, TX
# Retrieving restaurant 34 in Austin, TX
# Retrieving restaurant 35 in Austin, TX
# Retrieving restaurant 36 in Austin, TX
# Retrieving restaurant 37 in Austin, TX
# Retrieving restaurant 38 in Austin, TX
# Retrieving restaurant 39 in Austin, TX
# Retrieving restaurant 40 in Austin, TX
# Retrieving restaurant 41 in Austin, TX
# Retrieving restaurant 42 in Austin, TX
# Retrieving restaurant 43 in Austin, TX
# Retrieving restaurant 44 in Austin, TX
# Retrieving restaurant 45 in Austin, TX
# Retrieving restaurant 46 in Austin, TX
# Retrieving restaurant 47 in Austin, TX
# Retrieving restaurant 48 in Austin, TX
# Retrieving restaurant 49 in Austin, TX
# Retrieving restaurant 50 in Austin, TX

# %%
# Create DataFrame
restaurants_pd = pd.DataFrame({'Name' : name_list, 'City' : city_list, 'State' : state_list, 'Category' : category_list, 
                               'Rating' : rating_list, 'Review Count' : review_count_list, 'Price' : price_list})

restaurants_pd.head()
# Out:
#             Name      City State            Category  Rating  Review Count  \
# 0  Tasty n Alder  Portland    OR      American (New)     4.5          3463
# 1  Tasty n Alder  Portland    OR  Breakfast & Brunch     4.5          3463
# 2  Tasty n Alder  Portland    OR         Steakhouses     4.5          3463
# 3    Screen Door  Portland    OR            Southern     4.5          6370
# 4    Screen Door  Portland    OR        Cajun/Creole     4.5          6370
#
#   Price
# 0    $$
# 1    $$
# 2    $$
# 3    $$
# 4    $$

# %%
# Cleanup

restaurants_pd['Price'].replace({'$$$$$' : 5, '$$$$' : 4, '$$$' : 3, '$$' : 2, '$' : 1}, inplace = True)

# Will need to be excluded in Price charts
# restaurants_pd.loc[restaurants_pd.Price == '']

restaurants_pd['Category'].replace(['American (New)', 'American (Traditional)'], 'American', inplace = True)
restaurants_pd['Category'].replace(['Beer Bar', 'Beer, Wine & Spirits', 'Brewpubs', 'Cocktail Bars', 
                                    'Wine Bars', 'Beer Gardens', 'Pubs', 'Gastropubs'], 'Bars', inplace = True)
restaurants_pd['Category'].replace(['Coffee & Tea', 'Bubble Tea', 'Hong Kong Style Cafe'], 'Cafes', inplace = True)
restaurants_pd['Category'].replace(['Cupcakes', 'Custom Cakes'], 'Desserts', inplace = True)
restaurants_pd['Category'].replace(['Seafood Markets'], 'Seafood', inplace = True)
restaurants_pd['Category'].replace(['Smokehouse'], 'Barbeque', inplace = True)
restaurants_pd['Category'].replace(['Food Stands', 'Food Trucks', 'Street Vendors'], 'Food Stands/Trucks', inplace = True)
restaurants_pd['Category'].replace(['Empanadas'], 'Latin American', inplace = True)
restaurants_pd['Category'].replace(['Japanese Curry'], 'Japanese', inplace = True)
restaurants_pd['Category'].replace(['New Mexican Cuisine'], 'Mexican', inplace = True)
restaurants_pd['Category'].replace(['Cheesesteaks'], 'Sandwiches', inplace = True)


restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Bookstores']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Home Decor']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Music Venues']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Lounges']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Food']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Caterers']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Cheese Shops']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Tabletop Games']
restaurants_pd = restaurants_pd[restaurants_pd.Category != 'Venues & Event Spaces']

len(restaurants_pd)
# Out:
# 1023

# %%
# cleanup_pd = pd.DataFrame(restaurants_pd.groupby(['Category'])['Name'].count())
# cleanup_pd.to_csv('cleanup.csv')

# restaurants_pd.loc[restaurants_pd.Category == 'Street Vendors']
# restaurants_pd.loc[restaurants_pd.Name == "Dirt Dog - Las Vegas Strip"]

# %%
# len(restaurants_pd)

portland_pd = restaurants_pd[restaurants_pd.City == 'Portland']
sanfrancisco_pd = restaurants_pd[restaurants_pd.City == 'San Francisco']
miami_pd = restaurants_pd[restaurants_pd.City == 'Miami']
newyork_pd = restaurants_pd[restaurants_pd.City == 'New York']
losangeles_pd = restaurants_pd[restaurants_pd.City == 'Los Angeles']
orlando_pd = restaurants_pd[restaurants_pd.City == 'Orlando']
lasvegas_pd = restaurants_pd[restaurants_pd.City == 'Las Vegas']
seattle_pd = restaurants_pd[restaurants_pd.City == 'Seattle']
sandiego_pd = restaurants_pd[restaurants_pd.City == 'San Diego']
austin_pd = restaurants_pd[restaurants_pd.City == 'Austin']

# %%
portland_pd
# Out:
#                          Name      City State            Category  Rating  \
# 0               Tasty n Alder  Portland    OR            American     4.5
# 1               Tasty n Alder  Portland    OR  Breakfast & Brunch     4.5
# 2               Tasty n Alder  Portland    OR         Steakhouses     4.5
# 3                 Screen Door  Portland    OR            Southern     4.5
# 4                 Screen Door  Portland    OR        Cajun/Creole     4.5
# 5                 Screen Door  Portland    OR  Breakfast & Brunch     4.5
# 6                       MAC’D  Portland    OR        Comfort Food     4.0
# 7                     Bao Bao  Portland    OR  Food Stands/Trucks     4.5
# 8                     Bao Bao  Portland    OR             Dim Sum     4.5
# 9                     Lúc Lác  Portland    OR          Vietnamese     4.0
# 10                    Lúc Lác  Portland    OR  Tapas/Small Plates     4.0
# 11                    Lúc Lác  Portland    OR                Bars     4.0
# 12        Nong's Khao Man Gai  Portland    OR                Thai     4.5
# 13        Nong's Khao Man Gai  Portland    OR        Chicken Shop     4.5
# 14        Nong's Khao Man Gai  Portland    OR                Bars     4.5
# 18        Pine State Biscuits  Portland    OR            Southern     4.5
# 19        Pine State Biscuits  Portland    OR  Breakfast & Brunch     4.5
# 20        Pine State Biscuits  Portland    OR          Sandwiches     4.5
# 21                    Pok Pok  Portland    OR                Thai     4.0
# 22                    Pok Pok  Portland    OR          Vietnamese     4.0
# 23                    Pok Pok  Portland    OR           Pan Asian     4.0
# 24                       TILT  Portland    OR             Burgers     4.0
# 25                       TILT  Portland    OR                Bars     4.0
# 26                       TILT  Portland    OR          Sandwiches     4.0
# 27               Peri Koshari  Portland    OR      Middle Eastern     5.0
# 28               Peri Koshari  Portland    OR  Food Stands/Trucks     5.0
# 29         Portland Food Hall  Portland    OR          Food Court     4.0
# 30   808 Grinds Hawaiian Cafe  Portland    OR            Hawaiian     4.5
# 31                      Lardo  Portland    OR          Sandwiches     4.0
# 32            The Observatory  Portland    OR            American     4.5
# ..                        ...       ...   ...                 ...     ...
# 75                  Phat Cart  Portland    OR  Breakfast & Brunch     4.5
# 76   LoveVerona Pizza & Pasta  Portland    OR               Pizza     4.5
# 77   LoveVerona Pizza & Pasta  Portland    OR             Italian     4.5
# 78   LoveVerona Pizza & Pasta  Portland    OR  Food Stands/Trucks     4.5
# 79                    Sammich  Portland    OR               Delis     4.5
# 80                    Sammich  Portland    OR          Sandwiches     4.5
# 81                    Sammich  Portland    OR             Burgers     4.5
# 82             Danwei Canting  Portland    OR             Chinese     4.0
# 83     Dr Philly Cheese Steak  Portland    OR          Sandwiches     4.5
# 84     Dr Philly Cheese Steak  Portland    OR      Street Vendors     4.5
# 85         Pine Street Market  Portland    OR               Cafes     4.0
# 86         Pine Street Market  Portland    OR      Specialty Food     4.0
# 87         Pine Street Market  Portland    OR                Bars     4.0
# 88         Stretch the Noodle  Portland    OR             Noodles     4.5
# 89         Stretch the Noodle  Portland    OR             Chinese     4.5
# 90         Stretch the Noodle  Portland    OR  Food Stands/Trucks     4.5
# 91     Elephants Delicatessen  Portland    OR                Soup     4.5
# 92     Elephants Delicatessen  Portland    OR            American     4.5
# 93     Elephants Delicatessen  Portland    OR               Pizza     4.5
# 94       Fire On the Mountain  Portland    OR       Chicken Wings     4.0
# 95       Fire On the Mountain  Portland    OR            Barbeque     4.0
# 96       Fire On the Mountain  Portland    OR            American     4.0
# 97           The Baker's Mark  Portland    OR          Sandwiches     4.5
# 98           The Baker's Mark  Portland    OR               Salad     4.5
# 99                      South  Portland    OR            Southern     5.0
# 100                     South  Portland    OR  Food Stands/Trucks     5.0
# 101             Marukin Ramen  Portland    OR               Ramen     4.0
# 102             Marukin Ramen  Portland    OR             Noodles     4.0
# 103                   Richi's  Portland    OR            Japanese     4.5
# 104      Por Que No? Taqueria  Portland    OR             Mexican     4.0
#
#      Review Count Price
# 0            3463     2
# 1            3463     2
# 2            3463     2
# 3            6370     2
# 4            6370     2
# 5            6370     2
# 6              38
# 7              92     1
# 8              92     1
# 9            2676     2
# 10           2676     2
# 11           2676     2
# 12           1437     2
# 13           1437     2
# 14           1437     2
# 18           3295     1
# 19           3295     1
# 20           3295     1
# 21           5776     2
# 22           5776     2
# 23           5776     2
# 24           1248     2
# 25           1248     2
# 26           1248     2
# 27              9
# 28              9
# 29             20     2
# 30            415     2
# 31           1109     2
# 32           1675     2
# ..            ...   ...
# 75            166     1
# 76            172     1
# 77            172     1
# 78            172     1
# 79            107     2
# 80            107     2
# 81            107     2
# 82            354     2
# 83              2
# 84              2
# 85            334     2
# 86            334     2
# 87            334     2
# 88            161     1
# 89            161     1
# 90            161     1
# 91            626     2
# 92            626     2
# 93            626     2
# 94            994     2
# 95            994     2
# 96            994     2
# 97            131     1
# 98            131     1
# 99              3
# 100             3
# 101           478     2
# 102           478     2
# 103            38     1
# 104          1145     2
#
# [101 rows x 7 columns]
